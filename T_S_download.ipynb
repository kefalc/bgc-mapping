# %%
#This code can be used to download T&S Data files (prof.nc) from the ARGO GDAC

#Set up

# Import packages
import numpy as np
import pandas as pd
from scipy import interpolate
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from datetime import datetime, timedelta
import requests
import time
import os
import urllib3
import shutil
import plotly.graph_objects as go
import cmocean

# Base filepath
root = '/global/u2/k/kefalc/code/'
profile_dir = root + 'Profiles/'
natl_dir = root + 'Test_Data/'#Change this for other projects

# Create GO-BGC folders if they do not exist yet
#if 'Profiles' not in os.listdir(root):
#  os.mkdir(profile_dir)
#if 'Test_Data' not in os.listdir(profile_dir): #Change this for other projects
#  os.mkdir(natl_dir)

# %%
# Function to download a single file
def download_file(url_path,filename,save_to=None,overwrite=False,verbose=True):
    """ Downloads and saves a file from a given URL using HTTP protocol.

    Note: If '404 file not found' error returned, function will return without downloading anything.
    
    Arguments:
        url_path: root URL to download from including trailing slash ('/')
        filename: filename to download including suffix
        save_to: None (to download to root Google Drive GO-BGC directory)
                 or directory path
        overwrite: False to leave existing files in place
                   or True to overwrite existing files
        verbose: True to announce progress
                 or False to stay silent
    
    """
    urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

    if save_to is None:
      save_to = root

    try:
      if filename in os.listdir(save_to):
          if not overwrite:
              if verbose: print('>>> File ' + filename + ' already exists. Leaving current version.')
              return
          else:
              if verbose: print('>>> File ' + filename + ' already exists. Overwriting with new version.')

      def get_func(url,stream=True):
          try:
              return requests.get(url,stream=stream,auth=None,verify=False)
          except requests.exceptions.ConnectionError as error_tag:
              print('Error connecting:',error_tag)
              time.sleep(1)
              return get_func(url,stream=stream)

      response = get_func(url_path + filename,stream=True)

      if response.status_code == 404:
          if verbose: print('>>> File ' + filename + ' returned 404 error during download.')
          return
      with open(save_to + filename,'wb') as out_file:
          shutil.copyfileobj(response.raw,out_file)
      del response
      if verbose: print('>>> Successfully downloaded ' + filename + '.')

    except:
      if verbose: print('>>> An error occurred while trying to download ' + filename + '.')

# %%
# Function to download and parse GDAC synthetic profile index file
def argo_gdac(lat_range=None,lon_range=None,start_date=None,end_date=None,sensors=None,floats=None,
              overwrite_index=False,overwrite_profiles=False,skip_download=False,
              download_individual_profs=False,save_to=None,verbose=True):
  """ Downloads GDAC Global Index File (For T & S data), then selects float profiles based on criteria.
      Either returns information on profiles and floats (if skip_download=True) or downloads them (if False).

      Arguments:
          lat_range: None, to select all latitudes
                     or [lower, upper] within -90 to 90 (selection is inclusive)
          lon_range: None, to select all longitudes
                     or [lower, upper] within either -180 to 180 or 0 to 360 (selection is inclusive)
                     NOTE: longitude range is allowed to cross -180/180 or 0/360
          start_date: None or datetime object
          end_date:   None or datetime object
          sensors: None, to select profiles with any combination of sensors
                   or string or list of strings to specify required sensors
                   > note that common options include PRES, TEMP, PSAL, DOXY, CHLA, BBP700,
                                                      PH_IN_SITU_TOTAL, and NITRATE
          floats: None, to select any floats matching other criteria
                  or int or list of ints specifying floats' WMOID numbers
          overwrite_index: False to keep existing downloaded GDAC index file, or True to download new index
          overwrite_profiles: False to keep existing downloaded profile files, or True to download new files
          skip_download: True to skip download and return: (<list of WMOIDs>, <DataFrame of index file subset>,
                                                            <list of downloaded filenames [if applicable]>)
                         or False to download those profiles
          download_individual_profs: False to download single file containing all profiles for each float
                                     or True to download individual profile files for each float
          save_to: None to download to Google Drive "/GO-BGC Workshop/Profiles" directory
                   or string to specify directory path for profile downloads
          verbose: True to announce progress, or False to stay silent

  """
  # Paths #THIS SECTION NEEDS TO BE FIXED TO INCLUDE ALL T&S
  url_root = 'https://www.usgodae.org/ftp/outgoing/argo/'
  dac_url_root = url_root + 'dac/'
  index_filename = 'ar_index_global_prof.txt' 
  if save_to is None: save_to = root

  # Download GDAC synthetic profile index file
  download_file(url_root,index_filename,overwrite=overwrite_index)

  # Load index file into Pandas DataFrame
  gdac_index = pd.read_csv(root + index_filename,delimiter=',',header=8,parse_dates=['date','date_update'],
                          date_parser=lambda x: pd.to_datetime(x,format='%Y%m%d%H%M%S'))

  # Establish time and space criteria
  if lat_range is None:  lat_range = [-90.0,90.0]
  if lon_range is None:  lon_range = [-180.0,180.0]
  elif lon_range[0] > 180 or lon_range[1] > 180:
    if lon_range[0] > 180: lon_range[0] -= 360
    if lon_range[1] > 180: lon_range[1] -= 360
  if start_date is None: start_date = datetime(1900,1,1)
  if end_date is None:   end_date = datetime(2200,1,1)

  float_wmoid_regexp = r'[a-z]*/[0-9]*/profiles/[A-Z]*([0-9]*)_[0-9]*[A-Z]*.nc'
  gdac_index['wmoid'] = gdac_index['file'].str.extract(float_wmoid_regexp).astype(int)
  filepath_main_regexp = '([a-z]*/[0-9]*/)profiles/[A-Z]*[0-9]*_[0-9]*[A-Z]*.nc'
  gdac_index['filepath_main'] = gdac_index['file'].str.extract(filepath_main_regexp)
  filepath_regexp = '([a-z]*/[0-9]*/profiles/)[A-Z]*[0-9]*_[0-9]*[A-Z]*.nc'
  gdac_index['filepath'] = gdac_index['file'].str.extract(filepath_regexp)
  filename_regexp = '[a-z]*/[0-9]*/profiles/([A-Z]*[0-9]*_[0-9]*[A-Z]*.nc)'
  gdac_index['filename'] = gdac_index['file'].str.extract(filename_regexp)

  # Subset profiles based on time and space criteria
  gdac_index_subset = gdac_index.loc[np.logical_and.reduce([gdac_index['latitude'] >= lat_range[0],
                                                            gdac_index['latitude'] <= lat_range[1],
                                                            gdac_index['date'] >= start_date,
                                                            gdac_index['date'] <= end_date]),:]
  if lon_range[1] >= lon_range[0]:    # range does not cross -180/180 or 0/360
    gdac_index_subset = gdac_index_subset.loc[np.logical_and(gdac_index_subset['longitude'] >= lon_range[0],
                                                             gdac_index_subset['longitude'] <= lon_range[1])]
  elif lon_range[1] < lon_range[0]:   # range crosses -180/180 or 0/360
    gdac_index_subset = gdac_index_subset.loc[np.logical_or(gdac_index_subset['longitude'] >= lon_range[0],
                                                            gdac_index_subset['longitude'] <= lon_range[1])]

  # If requested, subset profiles using float WMOID criteria
  if floats is not None:
    if type(floats) is not list: floats = [floats]
    gdac_index_subset = gdac_index_subset.loc[gdac_index_subset['wmoid'].isin(floats),:]

  # If requested, subset profiles using sensor criteria
  if sensors is not None:
    if type(sensors) is not list: sensors = [sensors]
    for sensor in sensors:
      gdac_index_subset = gdac_index_subset.loc[gdac_index_subset['parameters'].str.contains(sensor),:]

  # Examine subsetted profiles
  wmoids = gdac_index_subset['wmoid'].unique()
  wmoid_filepaths = gdac_index_subset['filepath_main'].unique()

  # Just return list of floats and DataFrame with subset of index file, or download each profile
  if not skip_download:
    downloaded_filenames = []
    if download_individual_profs:
      for p_idx in gdac_index_subset.index:
        download_file(dac_url_root + gdac_index_subset.loc[p_idx]['filepath'],
                      gdac_index_subset.loc[p_idx]['filename'],
                      save_to=save_to,overwrite=overwrite_profiles,verbose=verbose)
        downloaded_filenames.append(gdac_index_subset.loc[p_idx]['filename'])
    else:
      for f_idx, wmoid_filepath in enumerate(wmoid_filepaths):
        download_file(dac_url_root + wmoid_filepath,str(wmoids[f_idx]) + '_prof.nc',
                      save_to=save_to,overwrite=overwrite_profiles,verbose=verbose)
        downloaded_filenames.append(str(wmoids[f_idx]) + '_prof.nc')
    return wmoids, gdac_index_subset, downloaded_filenames
  else:
    return wmoids, gdac_index_subset

# %%
wmoids, gdac_index, downloaded_filenames \
                  = argo_gdac(lat_range=[-60, -40], lon_range=[-140, -130],start_date=None,end_date=None,sensors=None,floats=None,
                    overwrite_index=False,overwrite_profiles=False, skip_download=False,download_individual_profs=False,
                    save_to=natl_dir,verbose=True)
# Out:
# >>> File ar_index_global_prof.txt already exists. Leaving current version.
# >>> File 1900190_prof.nc already exists. Leaving current version.
# >>> File 1900194_prof.nc already exists. Leaving current version.
# >>> File 1900724_prof.nc already exists. Leaving current version.
# >>> File 1900805_prof.nc already exists. Leaving current version.
# >>> File 1900810_prof.nc already exists. Leaving current version.
# >>> File 1900812_prof.nc already exists. Leaving current version.
# >>> File 1900978_prof.nc already exists. Leaving current version.
# >>> File 1900980_prof.nc already exists. Leaving current version.
# >>> File 1901385_prof.nc already exists. Leaving current version.
# >>> File 1901386_prof.nc already exists. Leaving current version.
# >>> File 1901403_prof.nc already exists. Leaving current version.
# >>> File 1901407_prof.nc already exists. Leaving current version.
# >>> File 1901408_prof.nc already exists. Leaving current version.
# >>> File 1901411_prof.nc already exists. Leaving current version.
# >>> File 1901413_prof.nc already exists. Leaving current version.
# >>> File 1901414_prof.nc already exists. Leaving current version.
# >>> File 1901415_prof.nc already exists. Leaving current version.
# >>> File 1901440_prof.nc already exists. Leaving current version.
# >>> File 2900108_prof.nc already exists. Leaving current version.
# >>> File 2900109_prof.nc already exists. Leaving current version.
# >>> File 2900111_prof.nc already exists. Leaving current version.
# >>> File 2900112_prof.nc already exists. Leaving current version.
# >>> File 2900133_prof.nc already exists. Leaving current version.
# >>> File 3900508_prof.nc already exists. Leaving current version.
# >>> File 3900633_prof.nc already exists. Leaving current version.
# >>> File 3900817_prof.nc already exists. Leaving current version.
# >>> File 3901129_prof.nc already exists. Leaving current version.
# >>> File 3901471_prof.nc already exists. Leaving current version.
# >>> File 4900475_prof.nc already exists. Leaving current version.
# >>> File 5900214_prof.nc already exists. Leaving current version.
# >>> File 5900242_prof.nc already exists. Leaving current version.
# >>> File 5900243_prof.nc already exists. Leaving current version.
# >>> File 5900244_prof.nc already exists. Leaving current version.
# >>> File 5900247_prof.nc already exists. Leaving current version.
# >>> File 5900250_prof.nc already exists. Leaving current version.
# >>> File 5900252_prof.nc already exists. Leaving current version.
# >>> File 5900264_prof.nc already exists. Leaving current version.
# >>> File 5900321_prof.nc already exists. Leaving current version.
# >>> File 5900322_prof.nc already exists. Leaving current version.
# >>> File 5900323_prof.nc already exists. Leaving current version.
# >>> File 5900428_prof.nc already exists. Leaving current version.
# >>> File 5900454_prof.nc already exists. Leaving current version.
# >>> File 5900455_prof.nc already exists. Leaving current version.
# >>> File 5900456_prof.nc already exists. Leaving current version.
# >>> File 5900458_prof.nc already exists. Leaving current version.
# >>> File 5900459_prof.nc already exists. Leaving current version.
# >>> File 5900469_prof.nc already exists. Leaving current version.
# >>> File 5900470_prof.nc already exists. Leaving current version.
# >>> File 5900527_prof.nc already exists. Leaving current version.
# >>> File 5900528_prof.nc already exists. Leaving current version.
# >>> File 5900532_prof.nc already exists. Leaving current version.
# >>> File 5900534_prof.nc already exists. Leaving current version.
# >>> File 5900535_prof.nc already exists. Leaving current version.
# >>> File 5900696_prof.nc already exists. Leaving current version.
# >>> File 5900702_prof.nc already exists. Leaving current version.
# >>> File 5900703_prof.nc already exists. Leaving current version.
# >>> File 5900704_prof.nc already exists. Leaving current version.
# >>> File 5900705_prof.nc already exists. Leaving current version.
# >>> File 5900706_prof.nc already exists. Leaving current version.
# >>> File 5900707_prof.nc already exists. Leaving current version.
# >>> File 5900717_prof.nc already exists. Leaving current version.
# >>> File 5900720_prof.nc already exists. Leaving current version.
# >>> File 5900721_prof.nc already exists. Leaving current version.
# >>> File 5900722_prof.nc already exists. Leaving current version.
# >>> File 5900771_prof.nc already exists. Leaving current version.
# >>> File 5900774_prof.nc already exists. Leaving current version.
# >>> File 5900776_prof.nc already exists. Leaving current version.
# >>> File 5900778_prof.nc already exists. Leaving current version.
# >>> File 5900779_prof.nc already exists. Leaving current version.
# >>> File 5900780_prof.nc already exists. Leaving current version.
# >>> File 5900781_prof.nc already exists. Leaving current version.
# >>> File 5900782_prof.nc already exists. Leaving current version.
# >>> File 5900783_prof.nc already exists. Leaving current version.
# >>> File 5900784_prof.nc already exists. Leaving current version.
# >>> File 5900826_prof.nc already exists. Leaving current version.
# >>> File 5900827_prof.nc already exists. Leaving current version.
# >>> File 5900828_prof.nc already exists. Leaving current version.
# >>> File 5900829_prof.nc already exists. Leaving current version.
# >>> File 5900830_prof.nc already exists. Leaving current version.
# >>> File 5900831_prof.nc already exists. Leaving current version.
# >>> File 5900833_prof.nc already exists. Leaving current version.
# >>> File 5900834_prof.nc already exists. Leaving current version.
# >>> File 5900835_prof.nc already exists. Leaving current version.
# >>> File 5900836_prof.nc already exists. Leaving current version.
# >>> File 5900894_prof.nc already exists. Leaving current version.
# >>> File 5900895_prof.nc already exists. Leaving current version.
# >>> File 5900896_prof.nc already exists. Leaving current version.
# >>> File 5900897_prof.nc already exists. Leaving current version.
# >>> File 5900898_prof.nc already exists. Leaving current version.
# >>> File 5900900_prof.nc already exists. Leaving current version.
# >>> File 5900930_prof.nc already exists. Leaving current version.
# >>> File 5900931_prof.nc already exists. Leaving current version.
# >>> File 5900932_prof.nc already exists. Leaving current version.
# >>> File 5900933_prof.nc already exists. Leaving current version.
# >>> File 5900966_prof.nc already exists. Leaving current version.
# >>> File 5900987_prof.nc already exists. Leaving current version.
# >>> File 5900988_prof.nc already exists. Leaving current version.
# >>> File 5900999_prof.nc already exists. Leaving current version.
# >>> File 5901000_prof.nc already exists. Leaving current version.
# >>> File 5901001_prof.nc already exists. Leaving current version.
# >>> File 5901002_prof.nc already exists. Leaving current version.
# >>> File 5901032_prof.nc already exists. Leaving current version.
# >>> File 5901033_prof.nc already exists. Leaving current version.
# >>> File 5901046_prof.nc already exists. Leaving current version.
# >>> File 5901048_prof.nc already exists. Leaving current version.
# >>> File 5901050_prof.nc already exists. Leaving current version.
# >>> File 5901051_prof.nc already exists. Leaving current version.
# >>> File 5901052_prof.nc already exists. Leaving current version.
# >>> File 5901053_prof.nc already exists. Leaving current version.
# >>> File 5901065_prof.nc already exists. Leaving current version.
# >>> File 5901067_prof.nc already exists. Leaving current version.
# >>> File 5901068_prof.nc already exists. Leaving current version.
# >>> File 5901091_prof.nc already exists. Leaving current version.
# >>> File 5901104_prof.nc already exists. Leaving current version.
# >>> File 5901105_prof.nc already exists. Leaving current version.
# >>> File 5901106_prof.nc already exists. Leaving current version.
# >>> File 5901227_prof.nc already exists. Leaving current version.
# >>> File 5901252_prof.nc already exists. Leaving current version.
# >>> File 5901321_prof.nc already exists. Leaving current version.
# >>> File 5901326_prof.nc already exists. Leaving current version.
# >>> File 5901327_prof.nc already exists. Leaving current version.
# >>> File 5901377_prof.nc already exists. Leaving current version.
# >>> File 5901378_prof.nc already exists. Leaving current version.
# >>> File 5901384_prof.nc already exists. Leaving current version.
# >>> File 5901425_prof.nc already exists. Leaving current version.
# >>> File 5901426_prof.nc already exists. Leaving current version.
# >>> File 5901427_prof.nc already exists. Leaving current version.
# >>> File 5901429_prof.nc already exists. Leaving current version.
# >>> File 5901488_prof.nc already exists. Leaving current version.
# >>> File 5901764_prof.nc already exists. Leaving current version.
# >>> File 5901803_prof.nc already exists. Leaving current version.
# >>> File 5901820_prof.nc already exists. Leaving current version.
# >>> File 5901821_prof.nc already exists. Leaving current version.
# >>> File 5901822_prof.nc already exists. Leaving current version.
# >>> File 5901823_prof.nc already exists. Leaving current version.
# >>> File 5901824_prof.nc already exists. Leaving current version.
# >>> File 5901826_prof.nc already exists. Leaving current version.
# >>> File 5901827_prof.nc already exists. Leaving current version.
# >>> File 5901828_prof.nc already exists. Leaving current version.
# >>> File 5901829_prof.nc already exists. Leaving current version.
# >>> File 5901841_prof.nc already exists. Leaving current version.
# >>> File 5901844_prof.nc already exists. Leaving current version.
# >>> File 5901848_prof.nc already exists. Leaving current version.
# >>> File 5901849_prof.nc already exists. Leaving current version.
# >>> File 5901851_prof.nc already exists. Leaving current version.
# >>> File 5901852_prof.nc already exists. Leaving current version.
# >>> File 5901853_prof.nc already exists. Leaving current version.
# >>> File 5901854_prof.nc already exists. Leaving current version.
# >>> File 5901855_prof.nc already exists. Leaving current version.
# >>> File 5901868_prof.nc already exists. Leaving current version.
# >>> File 5901870_prof.nc already exists. Leaving current version.
# >>> File 5901871_prof.nc already exists. Leaving current version.
# >>> File 5901872_prof.nc already exists. Leaving current version.
# >>> File 5901873_prof.nc already exists. Leaving current version.
# >>> File 5901874_prof.nc already exists. Leaving current version.
# >>> File 5901875_prof.nc already exists. Leaving current version.
# >>> File 5901876_prof.nc already exists. Leaving current version.
# >>> File 5901877_prof.nc already exists. Leaving current version.
# >>> File 5902102_prof.nc already exists. Leaving current version.
# >>> File 5902209_prof.nc already exists. Leaving current version.
# >>> File 5902222_prof.nc already exists. Leaving current version.
# >>> File 5902223_prof.nc already exists. Leaving current version.
# >>> File 5902250_prof.nc already exists. Leaving current version.
# >>> File 5902253_prof.nc already exists. Leaving current version.
# >>> File 5902256_prof.nc already exists. Leaving current version.
# >>> File 5902262_prof.nc already exists. Leaving current version.
# >>> File 5902334_prof.nc already exists. Leaving current version.
# >>> File 5902338_prof.nc already exists. Leaving current version.
# >>> File 5902339_prof.nc already exists. Leaving current version.
# >>> File 5902363_prof.nc already exists. Leaving current version.
# >>> File 5902365_prof.nc already exists. Leaving current version.
# >>> File 5902370_prof.nc already exists. Leaving current version.
# >>> File 5902371_prof.nc already exists. Leaving current version.
# >>> File 5902382_prof.nc already exists. Leaving current version.
# >>> File 5902383_prof.nc already exists. Leaving current version.
# >>> File 5902384_prof.nc already exists. Leaving current version.
# >>> File 5902385_prof.nc already exists. Leaving current version.
# >>> File 5902389_prof.nc already exists. Leaving current version.
# >>> File 5902390_prof.nc already exists. Leaving current version.
# >>> File 5902402_prof.nc already exists. Leaving current version.
# >>> File 5902403_prof.nc already exists. Leaving current version.
# >>> File 5902405_prof.nc already exists. Leaving current version.
# >>> File 5902406_prof.nc already exists. Leaving current version.
# >>> File 5902438_prof.nc already exists. Leaving current version.
# >>> File 5902439_prof.nc already exists. Leaving current version.
# >>> File 5902440_prof.nc already exists. Leaving current version.
# >>> File 5902453_prof.nc already exists. Leaving current version.
# >>> File 5902465_prof.nc already exists. Leaving current version.
# >>> File 5902466_prof.nc already exists. Leaving current version.
# >>> File 5902468_prof.nc already exists. Leaving current version.
# >>> File 5902482_prof.nc already exists. Leaving current version.
# >>> File 5902503_prof.nc already exists. Leaving current version.
# >>> File 5903284_prof.nc already exists. Leaving current version.
# >>> File 5903290_prof.nc already exists. Leaving current version.
# >>> File 5903295_prof.nc already exists. Leaving current version.
# >>> File 5903297_prof.nc already exists. Leaving current version.
# >>> File 5903311_prof.nc already exists. Leaving current version.
# >>> File 5903315_prof.nc already exists. Leaving current version.
# >>> File 5903323_prof.nc already exists. Leaving current version.
# >>> File 5903331_prof.nc already exists. Leaving current version.
# >>> File 5903332_prof.nc already exists. Leaving current version.
# >>> File 5903333_prof.nc already exists. Leaving current version.
# >>> File 5903334_prof.nc already exists. Leaving current version.
# >>> File 5903335_prof.nc already exists. Leaving current version.
# >>> File 5903336_prof.nc already exists. Leaving current version.
# >>> File 5903337_prof.nc already exists. Leaving current version.
# >>> File 5903338_prof.nc already exists. Leaving current version.
# >>> File 5903339_prof.nc already exists. Leaving current version.
# >>> File 5903340_prof.nc already exists. Leaving current version.
# >>> File 5903341_prof.nc already exists. Leaving current version.
# >>> File 5903342_prof.nc already exists. Leaving current version.
# >>> File 5903343_prof.nc already exists. Leaving current version.
# >>> File 5903344_prof.nc already exists. Leaving current version.
# >>> File 5903345_prof.nc already exists. Leaving current version.
# >>> File 5903347_prof.nc already exists. Leaving current version.
# >>> File 5903408_prof.nc already exists. Leaving current version.
# >>> File 5903439_prof.nc already exists. Leaving current version.
# >>> File 5903484_prof.nc already exists. Leaving current version.
# >>> File 5903493_prof.nc already exists. Leaving current version.
# >>> File 5903494_prof.nc already exists. Leaving current version.
# >>> File 5903495_prof.nc already exists. Leaving current version.
# >>> File 5903496_prof.nc already exists. Leaving current version.
# >>> File 5903509_prof.nc already exists. Leaving current version.
# >>> File 5903718_prof.nc already exists. Leaving current version.
# >>> File 5903721_prof.nc already exists. Leaving current version.
# >>> File 5903722_prof.nc already exists. Leaving current version.
# >>> File 5903810_prof.nc already exists. Leaving current version.
# >>> File 5903812_prof.nc already exists. Leaving current version.
# >>> File 5903813_prof.nc already exists. Leaving current version.
# >>> File 5903814_prof.nc already exists. Leaving current version.
# >>> File 5903815_prof.nc already exists. Leaving current version.
# >>> File 5903816_prof.nc already exists. Leaving current version.
# >>> File 5903817_prof.nc already exists. Leaving current version.
# >>> File 5903820_prof.nc already exists. Leaving current version.
# >>> File 5903849_prof.nc already exists. Leaving current version.
# >>> File 5903855_prof.nc already exists. Leaving current version.
# >>> File 5903875_prof.nc already exists. Leaving current version.
# >>> File 5903876_prof.nc already exists. Leaving current version.
# >>> File 5903877_prof.nc already exists. Leaving current version.
# >>> File 5903878_prof.nc already exists. Leaving current version.
# >>> File 5903880_prof.nc already exists. Leaving current version.
# >>> File 5903881_prof.nc already exists. Leaving current version.
# >>> File 5903882_prof.nc already exists. Leaving current version.
# >>> File 5903883_prof.nc already exists. Leaving current version.
# >>> File 5903885_prof.nc already exists. Leaving current version.
# >>> File 5903897_prof.nc already exists. Leaving current version.
# >>> File 5903898_prof.nc already exists. Leaving current version.
# >>> File 5903906_prof.nc already exists. Leaving current version.
# >>> File 5903907_prof.nc already exists. Leaving current version.
# >>> File 5903960_prof.nc already exists. Leaving current version.
# >>> File 5903961_prof.nc already exists. Leaving current version.
# >>> File 5903969_prof.nc already exists. Leaving current version.
# >>> File 5903989_prof.nc already exists. Leaving current version.
# >>> File 5904062_prof.nc already exists. Leaving current version.
# >>> File 5904065_prof.nc already exists. Leaving current version.
# >>> File 5904066_prof.nc already exists. Leaving current version.
# >>> File 5904077_prof.nc already exists. Leaving current version.
# >>> File 5904080_prof.nc already exists. Leaving current version.
# >>> File 5904081_prof.nc already exists. Leaving current version.
# >>> File 5904102_prof.nc already exists. Leaving current version.
# >>> File 5904103_prof.nc already exists. Leaving current version.
# >>> File 5904179_prof.nc already exists. Leaving current version.
# >>> File 5904185_prof.nc already exists. Leaving current version.
# >>> File 5904186_prof.nc already exists. Leaving current version.
# >>> File 5904188_prof.nc already exists. Leaving current version.
# >>> File 5904193_prof.nc already exists. Leaving current version.
# >>> File 5904194_prof.nc already exists. Leaving current version.
# >>> File 5904195_prof.nc already exists. Leaving current version.
# >>> File 5904196_prof.nc already exists. Leaving current version.
# >>> File 5904197_prof.nc already exists. Leaving current version.
# >>> File 5904198_prof.nc already exists. Leaving current version.
# >>> File 5904200_prof.nc already exists. Leaving current version.
# >>> File 5904396_prof.nc already exists. Leaving current version.
# >>> File 5904412_prof.nc already exists. Leaving current version.
# >>> File 5904416_prof.nc already exists. Leaving current version.
# >>> File 5904421_prof.nc already exists. Leaving current version.
# >>> File 5904425_prof.nc already exists. Leaving current version.
# >>> File 5904430_prof.nc already exists. Leaving current version.
# >>> File 5904435_prof.nc already exists. Leaving current version.
# >>> File 5904437_prof.nc already exists. Leaving current version.
# >>> File 5904481_prof.nc already exists. Leaving current version.
# >>> File 5904483_prof.nc already exists. Leaving current version.
# >>> File 5904528_prof.nc already exists. Leaving current version.
# >>> File 5904529_prof.nc already exists. Leaving current version.
# >>> File 5904533_prof.nc already exists. Leaving current version.
# >>> File 5904537_prof.nc already exists. Leaving current version.
# >>> File 5904596_prof.nc already exists. Leaving current version.
# >>> File 5904597_prof.nc already exists. Leaving current version.
# >>> File 5904598_prof.nc already exists. Leaving current version.
# >>> File 5904599_prof.nc already exists. Leaving current version.
# >>> File 5904607_prof.nc already exists. Leaving current version.
# >>> File 5904614_prof.nc already exists. Leaving current version.
# >>> File 5904617_prof.nc already exists. Leaving current version.
# >>> File 5904619_prof.nc already exists. Leaving current version.
# >>> File 5904652_prof.nc already exists. Leaving current version.
# >>> File 5904653_prof.nc already exists. Leaving current version.
# >>> File 5904673_prof.nc already exists. Leaving current version.
# >>> File 5904677_prof.nc already exists. Leaving current version.
# >>> File 5904683_prof.nc already exists. Leaving current version.
# >>> File 5904693_prof.nc already exists. Leaving current version.
# >>> File 5904695_prof.nc already exists. Leaving current version.
# >>> File 5904713_prof.nc already exists. Leaving current version.
# >>> File 5904761_prof.nc already exists. Leaving current version.
# >>> File 5904763_prof.nc already exists. Leaving current version.
# >>> File 5904766_prof.nc already exists. Leaving current version.
# >>> File 5904797_prof.nc already exists. Leaving current version.
# >>> File 5904803_prof.nc already exists. Leaving current version.
# >>> File 5904806_prof.nc already exists. Leaving current version.
# >>> File 5904808_prof.nc already exists. Leaving current version.
# >>> File 5905096_prof.nc already exists. Leaving current version.
# >>> File 5905098_prof.nc already exists. Leaving current version.
# >>> File 5905099_prof.nc already exists. Leaving current version.
# >>> File 5905103_prof.nc already exists. Leaving current version.
# >>> File 5905244_prof.nc already exists. Leaving current version.
# >>> File 5905245_prof.nc already exists. Leaving current version.
# >>> File 5905250_prof.nc already exists. Leaving current version.
# >>> File 5905251_prof.nc already exists. Leaving current version.
# >>> File 5905252_prof.nc already exists. Leaving current version.
# >>> File 5905253_prof.nc already exists. Leaving current version.
# >>> File 5905255_prof.nc already exists. Leaving current version.
# >>> File 5905267_prof.nc already exists. Leaving current version.
# >>> File 5905278_prof.nc already exists. Leaving current version.
# >>> File 5905279_prof.nc already exists. Leaving current version.
# >>> File 5905319_prof.nc already exists. Leaving current version.
# >>> File 5905320_prof.nc already exists. Leaving current version.
# >>> File 5905333_prof.nc already exists. Leaving current version.
# >>> File 5905352_prof.nc already exists. Leaving current version.
# >>> File 5905353_prof.nc already exists. Leaving current version.
# >>> File 5905371_prof.nc already exists. Leaving current version.
# >>> File 5905372_prof.nc already exists. Leaving current version.
# >>> File 5905377_prof.nc already exists. Leaving current version.
# >>> File 5905635_prof.nc already exists. Leaving current version.
# >>> File 5905660_prof.nc already exists. Leaving current version.
# >>> File 5905677_prof.nc already exists. Leaving current version.
# >>> File 5905678_prof.nc already exists. Leaving current version.
# >>> File 5905679_prof.nc already exists. Leaving current version.
# >>> File 5905680_prof.nc already exists. Leaving current version.
# >>> File 5905780_prof.nc already exists. Leaving current version.
# >>> File 5905781_prof.nc already exists. Leaving current version.
# >>> File 5905782_prof.nc already exists. Leaving current version.
# >>> File 5905783_prof.nc already exists. Leaving current version.
# >>> File 5905785_prof.nc already exists. Leaving current version.
# >>> File 5906058_prof.nc already exists. Leaving current version.
# >>> File 5906110_prof.nc already exists. Leaving current version.
# >>> File 5906116_prof.nc already exists. Leaving current version.
# >>> File 5906117_prof.nc already exists. Leaving current version.
# >>> File 5906121_prof.nc already exists. Leaving current version.
# >>> File 5906122_prof.nc already exists. Leaving current version.
# >>> File 5906196_prof.nc already exists. Leaving current version.
# >>> File 5906315_prof.nc already exists. Leaving current version.
# >>> File 5906316_prof.nc already exists. Leaving current version.
# >>> File 5906317_prof.nc already exists. Leaving current version.
# >>> File 5906360_prof.nc already exists. Leaving current version.
# >>> File 7900064_prof.nc already exists. Leaving current version.
# >>> File 7900065_prof.nc already exists. Leaving current version.
# >>> File 7900066_prof.nc already exists. Leaving current version.
# >>> File 7900067_prof.nc already exists. Leaving current version.
# >>> File 7900208_prof.nc already exists. Leaving current version.
# >>> File 7900209_prof.nc already exists. Leaving current version.
# >>> File 7900210_prof.nc already exists. Leaving current version.
# >>> File 7900211_prof.nc already exists. Leaving current version.
# >>> File 7900212_prof.nc already exists. Leaving current version.
# >>> File 7900213_prof.nc already exists. Leaving current version.
# >>> File 7900215_prof.nc already exists. Leaving current version.
# >>> File 7900216_prof.nc already exists. Leaving current version.
# >>> File 7900217_prof.nc already exists. Leaving current version.
# >>> File 7900296_prof.nc already exists. Leaving current version.
# >>> File 7900667_prof.nc already exists. Leaving current version.
# >>> File 7900668_prof.nc already exists. Leaving current version.
# >>> File 7900669_prof.nc already exists. Leaving current version.
# >>> File 7900670_prof.nc already exists. Leaving current version.
# >>> File 7900671_prof.nc already exists. Leaving current version.
# >>> File 7900672_prof.nc already exists. Leaving current version.
# >>> File 7900673_prof.nc already exists. Leaving current version.
# >>> File 7900674_prof.nc already exists. Leaving current version.
# >>> File 7900675_prof.nc already exists. Leaving current version.
# >>> File 7900676_prof.nc already exists. Leaving current version.
# >>> File 7900680_prof.nc already exists. Leaving current version.
# >>> File 7900682_prof.nc already exists. Leaving current version.
# >>> File 7900685_prof.nc already exists. Leaving current version.
# >>> File 7900686_prof.nc already exists. Leaving current version.
# >>> File 7900687_prof.nc already exists. Leaving current version.
# >>> File 7900688_prof.nc already exists. Leaving current version.
# >>> File 7900793_prof.nc already exists. Leaving current version.
# >>> File 7900794_prof.nc already exists. Leaving current version.
# >>> File 7900800_prof.nc already exists. Leaving current version.
# >>> File 1900343_prof.nc already exists. Leaving current version.
# >>> File 3901900_prof.nc already exists. Leaving current version.
# >>> File 3901904_prof.nc already exists. Leaving current version.
# >>> File 3901905_prof.nc already exists. Leaving current version.
# >>> File 3901906_prof.nc already exists. Leaving current version.
# >>> File 1901199_prof.nc already exists. Leaving current version.
# >>> File 6901814_prof.nc already exists. Leaving current version.
# >>> File 6901815_prof.nc already exists. Leaving current version.
# >>> File 6901838_prof.nc already exists. Leaving current version.
# >>> File 6901840_prof.nc already exists. Leaving current version.
# >>> File 6901841_prof.nc already exists. Leaving current version.
# >>> File 6901843_prof.nc already exists. Leaving current version.
# >>> File 6901849_prof.nc already exists. Leaving current version.
# >>> File 6901850_prof.nc already exists. Leaving current version.
# >>> File 6901856_prof.nc already exists. Leaving current version.
# >>> File 6901857_prof.nc already exists. Leaving current version.
# >>> File 6901872_prof.nc already exists. Leaving current version.
# >>> File 6901874_prof.nc already exists. Leaving current version.
# >>> File 6901875_prof.nc already exists. Leaving current version.
# >>> File 6901880_prof.nc already exists. Leaving current version.
# >>> File 6903182_prof.nc already exists. Leaving current version.
# >>> File 6903183_prof.nc already exists. Leaving current version.
# >>> File 6903187_prof.nc already exists. Leaving current version.
# >>> File 6903210_prof.nc already exists. Leaving current version.
# >>> File 6903211_prof.nc already exists. Leaving current version.
# >>> File 6903212_prof.nc already exists. Leaving current version.
# >>> File 6903213_prof.nc already exists. Leaving current version.
# >>> File 6903223_prof.nc already exists. Leaving current version.
# >>> File 6903231_prof.nc already exists. Leaving current version.
# >>> File 6903232_prof.nc already exists. Leaving current version.
# >>> File 6903233_prof.nc already exists. Leaving current version.
# >>> File 6903251_prof.nc already exists. Leaving current version.
# >>> File 6903252_prof.nc already exists. Leaving current version.
# >>> File 6903253_prof.nc already exists. Leaving current version.
# >>> File 6903254_prof.nc already exists. Leaving current version.
# >>> File 6903767_prof.nc already exists. Leaving current version.
# >>> File 6903768_prof.nc already exists. Leaving current version.
# >>> File 6903769_prof.nc already exists. Leaving current version.
# >>> File 6903770_prof.nc already exists. Leaving current version.
# >>> File 6903771_prof.nc already exists. Leaving current version.
# >>> File 2902741_prof.nc already exists. Leaving current version.
# >>> File 1901146_prof.nc already exists. Leaving current version.
# >>> File 1901155_prof.nc already exists. Leaving current version.
# >>> File 1901157_prof.nc already exists. Leaving current version.
# >>> File 1901734_prof.nc already exists. Leaving current version.
# >>> File 5900337_prof.nc already exists. Leaving current version.
# >>> File 5900339_prof.nc already exists. Leaving current version.
# >>> File 5900340_prof.nc already exists. Leaving current version.
# >>> File 5900342_prof.nc already exists. Leaving current version.
# >>> File 5900346_prof.nc already exists. Leaving current version.
# >>> File 5900348_prof.nc already exists. Leaving current version.
# >>> File 5900349_prof.nc already exists. Leaving current version.
# >>> File 5900842_prof.nc already exists. Leaving current version.
# >>> File 5900843_prof.nc already exists. Leaving current version.
# >>> File 5900845_prof.nc already exists. Leaving current version.
# >>> File 5900846_prof.nc already exists. Leaving current version.
# >>> File 5900874_prof.nc already exists. Leaving current version.
# >>> File 5900876_prof.nc already exists. Leaving current version.
# >>> File 5900877_prof.nc already exists. Leaving current version.
# >>> File 5900880_prof.nc already exists. Leaving current version.
# >>> File 5901134_prof.nc already exists. Leaving current version.
# >>> File 5901138_prof.nc already exists. Leaving current version.
# >>> File 5901139_prof.nc already exists. Leaving current version.
# >>> File 5901145_prof.nc already exists. Leaving current version.
# >>> File 5901148_prof.nc already exists. Leaving current version.
# >>> File 5901149_prof.nc already exists. Leaving current version.
# >>> File 5901150_prof.nc already exists. Leaving current version.
# >>> File 5901154_prof.nc already exists. Leaving current version.
# >>> File 5901156_prof.nc already exists. Leaving current version.
# >>> File 5901178_prof.nc already exists. Leaving current version.
# >>> File 5901181_prof.nc already exists. Leaving current version.
# >>> File 5901182_prof.nc already exists. Leaving current version.
# >>> File 5901183_prof.nc already exists. Leaving current version.
# >>> File 5901646_prof.nc already exists. Leaving current version.
# >>> File 5901647_prof.nc already exists. Leaving current version.
# >>> File 5901653_prof.nc already exists. Leaving current version.
# >>> File 5901654_prof.nc already exists. Leaving current version.
# >>> File 5901655_prof.nc already exists. Leaving current version.
# >>> File 5901656_prof.nc already exists. Leaving current version.
# >>> File 5901691_prof.nc already exists. Leaving current version.
# >>> File 5901692_prof.nc already exists. Leaving current version.
# >>> File 5901693_prof.nc already exists. Leaving current version.
# >>> File 5901698_prof.nc already exists. Leaving current version.
# >>> File 5901699_prof.nc already exists. Leaving current version.
# >>> File 5901706_prof.nc already exists. Leaving current version.
# >>> File 5901707_prof.nc already exists. Leaving current version.
# >>> File 5903225_prof.nc already exists. Leaving current version.
# >>> File 5903227_prof.nc already exists. Leaving current version.
# >>> File 5903230_prof.nc already exists. Leaving current version.
# >>> File 5903241_prof.nc already exists. Leaving current version.
# >>> File 5903242_prof.nc already exists. Leaving current version.
# >>> File 5903243_prof.nc already exists. Leaving current version.
# >>> File 5903244_prof.nc already exists. Leaving current version.
# >>> File 5903245_prof.nc already exists. Leaving current version.
# >>> File 5903246_prof.nc already exists. Leaving current version.
# >>> File 5903247_prof.nc already exists. Leaving current version.
# >>> File 5903248_prof.nc already exists. Leaving current version.
# >>> File 5903249_prof.nc already exists. Leaving current version.
# >>> File 5903250_prof.nc already exists. Leaving current version.
# >>> File 5903252_prof.nc already exists. Leaving current version.
# >>> File 5903254_prof.nc already exists. Leaving current version.
# >>> File 5903256_prof.nc already exists. Leaving current version.
# >>> File 5903260_prof.nc already exists. Leaving current version.
# >>> File 5903261_prof.nc already exists. Leaving current version.
# >>> File 5903262_prof.nc already exists. Leaving current version.
# >>> File 5903263_prof.nc already exists. Leaving current version.
# >>> File 5903264_prof.nc already exists. Leaving current version.
# >>> File 5903633_prof.nc already exists. Leaving current version.
# >>> File 5903642_prof.nc already exists. Leaving current version.
# >>> File 5903643_prof.nc already exists. Leaving current version.
# >>> File 5903646_prof.nc already exists. Leaving current version.
# >>> File 5903661_prof.nc already exists. Leaving current version.
# >>> File 5903662_prof.nc already exists. Leaving current version.
# >>> File 5903664_prof.nc already exists. Leaving current version.
# >>> File 5903665_prof.nc already exists. Leaving current version.
# >>> File 5903667_prof.nc already exists. Leaving current version.
# >>> File 5903668_prof.nc already exists. Leaving current version.
# >>> File 5903670_prof.nc already exists. Leaving current version.
# >>> File 5903672_prof.nc already exists. Leaving current version.
# >>> File 5903674_prof.nc already exists. Leaving current version.
# >>> File 5903675_prof.nc already exists. Leaving current version.
# >>> File 5903927_prof.nc already exists. Leaving current version.
# >>> File 5903929_prof.nc already exists. Leaving current version.
# >>> File 5903930_prof.nc already exists. Leaving current version.
# >>> File 5903931_prof.nc already exists. Leaving current version.
# >>> File 5903937_prof.nc already exists. Leaving current version.
# >>> File 5903938_prof.nc already exists. Leaving current version.
# >>> File 5903939_prof.nc already exists. Leaving current version.
# >>> File 5903940_prof.nc already exists. Leaving current version.
# >>> File 5903941_prof.nc already exists. Leaving current version.
# >>> File 5904219_prof.nc already exists. Leaving current version.
# >>> File 5904228_prof.nc already exists. Leaving current version.
# >>> File 5904229_prof.nc already exists. Leaving current version.
# >>> File 5904230_prof.nc already exists. Leaving current version.
# >>> File 5904233_prof.nc already exists. Leaving current version.
# >>> File 5904234_prof.nc already exists. Leaving current version.
# >>> File 5904235_prof.nc already exists. Leaving current version.
# >>> File 5904266_prof.nc already exists. Leaving current version.
# >>> File 5904267_prof.nc already exists. Leaving current version.
# >>> File 5904881_prof.nc already exists. Leaving current version.
# >>> File 5904883_prof.nc already exists. Leaving current version.
# >>> File 5904884_prof.nc already exists. Leaving current version.
# >>> File 5904885_prof.nc already exists. Leaving current version.
# >>> File 5904886_prof.nc already exists. Leaving current version.
# >>> File 5904887_prof.nc already exists. Leaving current version.
# >>> File 5904900_prof.nc already exists. Leaving current version.
# >>> File 5904919_prof.nc already exists. Leaving current version.
# >>> File 5904920_prof.nc already exists. Leaving current version.
# >>> File 5904921_prof.nc already exists. Leaving current version.
# >>> File 5904999_prof.nc already exists. Leaving current version.
# >>> File 5905002_prof.nc already exists. Leaving current version.
# >>> File 5905003_prof.nc already exists. Leaving current version.
# >>> File 5905005_prof.nc already exists. Leaving current version.
# >>> File 5905025_prof.nc already exists. Leaving current version.
# >>> File 5905028_prof.nc already exists. Leaving current version.
# >>> File 5905031_prof.nc already exists. Leaving current version.
# >>> File 5905032_prof.nc already exists. Leaving current version.
# >>> File 5905033_prof.nc already exists. Leaving current version.
# >>> File 5905034_prof.nc already exists. Leaving current version.
# >>> File 5905035_prof.nc already exists. Leaving current version.
# >>> File 5905036_prof.nc already exists. Leaving current version.
# >>> File 5905185_prof.nc already exists. Leaving current version.
# >>> File 5905186_prof.nc already exists. Leaving current version.
# >>> File 5905188_prof.nc already exists. Leaving current version.
# >>> File 5905394_prof.nc already exists. Leaving current version.
# >>> File 5905431_prof.nc already exists. Leaving current version.
# >>> File 5905443_prof.nc already exists. Leaving current version.
# >>> File 5905444_prof.nc already exists. Leaving current version.
# >>> File 7900308_prof.nc already exists. Leaving current version.
# >>> File 7900309_prof.nc already exists. Leaving current version.
# >>> File 7900315_prof.nc already exists. Leaving current version.
# >>> File 7900316_prof.nc already exists. Leaving current version.
# >>> File 7900318_prof.nc already exists. Leaving current version.
# >>> File 7900324_prof.nc already exists. Leaving current version.
# >>> File 7900326_prof.nc already exists. Leaving current version.
# >>> File 7900327_prof.nc already exists. Leaving current version.
# >>> File 7900332_prof.nc already exists. Leaving current version.
# >>> File 7900390_prof.nc already exists. Leaving current version.
# >>> File 7900391_prof.nc already exists. Leaving current version.
# >>> File 7900611_prof.nc already exists. Leaving current version.
# >>> File 7900618_prof.nc already exists. Leaving current version.
# >>> File 7900619_prof.nc already exists. Leaving current version.
# >>> File 7900620_prof.nc already exists. Leaving current version.
# >>> File 7900621_prof.nc already exists. Leaving current version.
# >>> File 7900626_prof.nc already exists. Leaving current version.
# >>> File 2901300_prof.nc already exists. Leaving current version.
# >>> File 2901301_prof.nc already exists. Leaving current version.
# >>> File 2901306_prof.nc already exists. Leaving current version.
# >>> File 2901348_prof.nc already exists. Leaving current version.
# >>> File 2901350_prof.nc already exists. Leaving current version.
# >>> File 2902224_prof.nc already exists. Leaving current version.
# >>> File 1900674_prof.nc already exists. Leaving current version.
# >>> File 1900675_prof.nc already exists. Leaving current version.
# >>> File 5900660_prof.nc already exists. Leaving current version.
# >>> File 5900787_prof.nc already exists. Leaving current version.
# >>> File 5900794_prof.nc already exists. Leaving current version.
# >>> File 5900795_prof.nc already exists. Leaving current version.
# >>> File 5900796_prof.nc already exists. Leaving current version.
# >>> File 5900797_prof.nc already exists. Leaving current version.
# >>> File 5900798_prof.nc already exists. Leaving current version.
# >>> File 5900799_prof.nc already exists. Leaving current version.
# >>> File 5900807_prof.nc already exists. Leaving current version.
# >>> File 5900815_prof.nc already exists. Leaving current version.
# >>> File 5901215_prof.nc already exists. Leaving current version.
# >>> File 5901507_prof.nc already exists. Leaving current version.
# >>> File 5901508_prof.nc already exists. Leaving current version.
# >>> File 5901509_prof.nc already exists. Leaving current version.
# >>> File 5901535_prof.nc already exists. Leaving current version.
# >>> File 5901536_prof.nc already exists. Leaving current version.
# >>> File 5901572_prof.nc already exists. Leaving current version.
# >>> File 5901601_prof.nc already exists. Leaving current version.
# >>> File 5904932_prof.nc already exists. Leaving current version.
# >>> File 5905216_prof.nc already exists. Leaving current version.
# >>> File 7900118_prof.nc already exists. Leaving current version.

# %%
print(len(downloaded_filenames))
# Out:
# 600

# %%
#plot locations of BGC and TS only float profiles

plt.figure(figsize=(12,6), facecolor='w')
plt.grid(alpha=0.5)
plt.xlim(-140, -130)
plt.ylim(-60, -40)

TS_folder=natl_dir
BGC_folder=profile_dir + 'Test_Data_BGC/'

for filename in os.listdir(TS_folder):
    data = xr.open_dataset(TS_folder + filename)
    data = data.rename({'CYCLE_NUMBER':'PROF_NUM'}).swap_dims({'N_PROF':'PROF_NUM'})
    data.plot.scatter('LONGITUDE','LATITUDE',c='g',s=10,alpha=0.5);
data.plot.scatter('LONGITUDE','LATITUDE',c='g',s=10,alpha=0.5,label='TS');#line needed to create legend
    
for filename in os.listdir(BGC_folder):
    data = xr.open_dataset(BGC_folder + filename)
    data = data.rename({'CYCLE_NUMBER':'PROF_NUM'}).swap_dims({'N_PROF':'PROF_NUM'})
    data.plot.scatter('LONGITUDE','LATITUDE',c='m',s=10);
data.plot.scatter('LONGITUDE','LATITUDE',c='m',s=10,label='BGC'); #line needed to create legend
    
plt.title("All Float Locations")
plt.legend(loc='upper right')

#save figure
#plt.savefig('BGC_TS_Locations.png')
